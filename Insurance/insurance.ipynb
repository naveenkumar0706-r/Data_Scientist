# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\navee\Desktop\Data_Scientist\phase 2\DAY 1\insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='red')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
X_test
# Out:
#     age
# 18   19
# 1    25
# 15   55
# 7    60
# 0    22
# 12   27

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 18   19
# 1    25
# 15   55
# 7    60
# 0    22
# 12   27

# %%
y_predicted = model.predict(X_test)

# %%
model.predict_proba(X_test)
# Out:
# array([[0.89132658, 0.10867342],
#        [0.80605861, 0.19394139],
#        [0.1219368 , 0.8780632 ],
#        [0.07305477, 0.92694523],
#        [0.85377012, 0.14622988],
#        [0.76817107, 0.23182893]])

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
y_predicted
# Out:
# array([0, 0, 1, 1, 0, 0])

# %%
X_test
# Out:
#     age
# 18   19
# 1    25
# 15   55
# 7    60
# 0    22
# 12   27

# %%
model.coef_
# Out:
# array([[0.11329387]])

# %%
model.intercept_
# Out:
# array([-4.25694727])

# %%
import math
def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %%
def prediction_function(age):
    z = 0.042 * age - 1.53 # 0.04150133 ~ 0.042 and -1.52726963 ~ -1.53
    y = sigmoid(z)
    return y

# %%
age = 35
prediction_function(age)
# Out:
# 0.4850044983805899

# %%
age = 43
prediction_function(age)
# Out:
# 0.568565299077705

# %%
plt.scatter(df.age, df.bought_insurance, color='red', marker='+', label='Actual Data')

age_range = np.linspace(df.age.min(), df.age.max(), 100)
probability = model.predict_proba(age_range.reshape(-1,1))[:,1]

plt.plot(age_range, probability, color='blue', linewidth=2, label='Logistic Regression Curve')

plt.xlabel("Age")
plt.ylabel("Probability of Buying Insurance")
plt.title("Logistic Regression Conclusion Graph")
plt.legend()

plt.show()
# Out:
# c:\Users\navee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
