# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from scipy.cluster.hierarchy import dendrogram, linkage

df = pd.read_excel("income.xlsx", names=["name", "age", "income"])
df
# Out:
#       name  age  income
# 0      Rob   29      45
# 1   Andrea   50      80
# 2    Mohan   35      52
# 3  Michael   32      41
# 4     Kory   36      87
# 5    David   48      68
# 6   Ismail   31      80
# 7   Sheela   55      60

# %%
sns.scatterplot(data=df, x="age", y="income", s =100)
plt.show()
X = df[["age", "income"]]

# %%
from sklearn.cluster import AgglomerativeClustering
h = AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage='average')
h.fit(X)
# Out:
# AgglomerativeClustering(linkage='average', n_clusters=3)

# %%
from scipy.cluster.hierarchy import dendrogram,linkage,fcluster
z=linkage(X,method='average')
z
# Out:
# array([[ 0.        ,  3.        ,  5.        ,  2.        ],
#        [ 4.        ,  6.        ,  8.60232527,  2.        ],
#        [ 2.        ,  8.        , 10.31064935,  3.        ],
#        [ 5.        ,  7.        , 10.63014581,  2.        ],
#        [ 1.        , 11.        , 16.39052659,  3.        ],
#        [ 9.        , 12.        , 23.69824661,  5.        ],
#        [10.        , 13.        , 33.65863823,  8.        ]])

# %%
plt.figure(figsize=(10,8))
plt.title('Hierachical Clustering')
dendrogram(z,labels=df['name'].values,leaf_rotation=90,leaf_font_size=10)
plt.xlabel("Sample Index")
plt.ylabel("Distance")
plt.show()

# %%
clusters = fcluster(z, 3, criterion='maxclust')
clusters
# Out:
# array([1, 3, 1, 1, 2, 3, 2, 3], dtype=int32)

# %%
df["clusters"] = clusters
df
# Out:
#       name  age  income  clustors  clusters
# 0      Rob   29      45         1         1
# 1   Andrea   50      80         3         3
# 2    Mohan   35      52         1         1
# 3  Michael   32      41         1         1
# 4     Kory   36      87         2         2
# 5    David   48      68         3         3
# 6   Ismail   31      80         2         2
# 7   Sheela   55      60         3         3
